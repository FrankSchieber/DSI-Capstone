# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import requests

# %matplotlib inline

api_key = {'69ea5b146d71755552f7bf90f18e3df0119641fd'}
api_key
# Out:
# {'69ea5b146d71755552f7bf90f18e3df0119641fd'}

# %%
ACS_16_1YR_DP02 = pd.read_csv('ACS_16_1YR_DP02_with_ann.csv')
ACS_16_1YR_DP03 = pd.read_csv('ACS_16_1YR_DP03_with_ann.csv')
ACS_16_1YR_DP04 = pd.read_csv('ACS_16_1YR_DP04_with_ann.csv')
ACS_16_1YR_DP05 = pd.read_csv('ACS_16_1YR_DP05_with_ann.csv')
frames = [ACS_16_1YR_DP02, ACS_16_1YR_DP03, ACS_16_1YR_DP04, ACS_16_1YR_DP05]
ACS_16_1YR = pd.concat(frames, axis=1)

ACS_16_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3120692     13161   3120692
# 48  0400000US53      53        Washington   2768076      8506   2768076
# 49  0400000US54      54     West Virginia    722125      5656    722125
# 50  0400000US55      55         Wisconsin   2326998      7745   2326998
# 51  0400000US56      56           Wyoming    223619      4088    223619
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...     HC03_VC108 HC04_VC108  \
# 47       (X)   2063049     16402      66.1    ...        6093779        (X)
# 48       (X)   1784043     12484      64.5    ...        5173515        (X)
# 49       (X)    467396      6711      64.7    ...        1438443        (X)
# 50       (X)   1460922      9966      62.8    ...        4351720        (X)
# 51       (X)    145524      4006      65.1    ...         433794        (X)
#
#    HC01_VC109 HC02_VC109 HC03_VC109 HC04_VC109 HC01_VC110 HC02_VC110  \
# ...

# %%
ACS_15_1YR_DP02 = pd.read_csv('ACS_15_1YR_DP02_with_ann.csv')
ACS_15_1YR_DP03 = pd.read_csv('ACS_15_1YR_DP03_with_ann.csv')
ACS_15_1YR_DP04 = pd.read_csv('ACS_15_1YR_DP04_with_ann.csv')
ACS_15_1YR_DP05 = pd.read_csv('ACS_15_1YR_DP05_with_ann.csv')
frames = [ACS_15_1YR_DP02, ACS_15_1YR_DP03, ACS_15_1YR_DP04, ACS_15_1YR_DP05]
ACS_15_1YR = pd.concat(frames, axis=1)

ACS_15_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3106895     11857   3106895
# 48  0400000US53      53        Washington   2728573      8477   2728573
# 49  0400000US54      54     West Virginia    734536      5346    734536
# 50  0400000US55      55         Wisconsin   2319538      7046   2319538
# 51  0400000US56      56           Wyoming    228937      3666    228937
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...     HC03_VC108 HC04_VC108  \
# 47       (X)   2054857     14080      66.1    ...        6062304        (X)
# 48       (X)   1760593     11977      64.5    ...        5081800        (X)
# 49       (X)    471947      7328      64.3    ...        1451557        (X)
# 50       (X)   1469666     10643      63.4    ...        4340567        (X)
# 51       (X)    145470      3828      63.5    ...         434584        (X)
#
#    HC01_VC109 HC02_VC109 HC03_VC109 HC04_VC109 HC01_VC110 HC02_VC110  \
# ...

# %%
ACS_14_1YR_DP02 = pd.read_csv('ACS_14_1YR_DP02_with_ann.csv')
ACS_14_1YR_DP03 = pd.read_csv('ACS_14_1YR_DP03_with_ann.csv')
ACS_14_1YR_DP04 = pd.read_csv('ACS_14_1YR_DP04_with_ann.csv')
ACS_14_1YR_DP05 = pd.read_csv('ACS_14_1YR_DP05_with_ann.csv')
frames = [ACS_14_1YR_DP02, ACS_14_1YR_DP03, ACS_14_1YR_DP04, ACS_14_1YR_DP05]
ACS_14_1YR = pd.concat(frames, axis=1)

ACS_14_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3083820     12955   3083820
# 48  0400000US53      53        Washington   2679601      9916   2679601
# 49  0400000US54      54     West Virginia    735375      6298    735375
# 50  0400000US55      55         Wisconsin   2307685      7753   2307685
# 51  0400000US56      56           Wyoming    232594      2987    232594
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...     HC03_VC101 HC04_VC101  \
# 47       (X)   2058820     15546      66.8    ...            0.1        0.1
# 48       (X)   1725099     12755      64.4    ...            0.1        0.1
# 49       (X)    472869      8027      64.3    ...            0.1        0.1
# 50       (X)   1485877     10597      64.4    ...            0.0        0.1
# 51       (X)    149032      3982      64.1    ...            0.0        0.1
#
#    HC01_VC102 HC02_VC102 HC03_VC102 HC04_VC102 HC01_VC104 HC02_VC104  \
# ...

# %%
ACS_13_1YR_DP02 = pd.read_csv('ACS_13_1YR_DP02_with_ann.csv')
ACS_13_1YR_DP03 = pd.read_csv('ACS_13_1YR_DP03_with_ann.csv')
ACS_13_1YR_DP04 = pd.read_csv('ACS_13_1YR_DP04_with_ann.csv')
ACS_13_1YR_DP05 = pd.read_csv('ACS_13_1YR_DP05_with_ann.csv')
frames = [ACS_13_1YR_DP02, ACS_13_1YR_DP03, ACS_13_1YR_DP04, ACS_13_1YR_DP05]
ACS_13_1YR = pd.concat(frames, axis=1)

ACS_13_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3055863     11608   3055863
# 48  0400000US53      53        Washington   2644557     11069   2644557
# 49  0400000US54      54     West Virginia    738653      5969    738653
# 50  0400000US55      55         Wisconsin   2289424      8727   2289424
# 51  0400000US56      56           Wyoming    224003      3223    224003
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...     HC03_VC101 HC04_VC101  \
# 47       (X)   2049184     16114      67.1    ...            0.1        0.1
# 48       (X)   1705112     13920      64.5    ...            0.1        0.1
# 49       (X)    479389      7296      64.9    ...            0.0        0.1
# 50       (X)   1458482     10630      63.7    ...            0.0        0.1
# 51       (X)    148556      4206      66.3    ...            0.0        0.1
#
#    HC01_VC102 HC02_VC102 HC03_VC102 HC04_VC102 HC01_VC104 HC02_VC104  \
# ...

# %%
ACS_12_1YR_DP02 = pd.read_csv('ACS_12_1YR_DP02_with_ann.csv')
ACS_12_1YR_DP03 = pd.read_csv('ACS_12_1YR_DP03_with_ann.csv')
ACS_12_1YR_DP04 = pd.read_csv('ACS_12_1YR_DP04_with_ann.csv')
ACS_12_1YR_DP05 = pd.read_csv('ACS_12_1YR_DP05_with_ann.csv')
frames = [ACS_12_1YR_DP02, ACS_12_1YR_DP03, ACS_12_1YR_DP04, ACS_12_1YR_DP05]
ACS_12_1YR = pd.concat(frames, axis=1)

ACS_12_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3038967     13344   3038967
# 48  0400000US53      53        Washington   2636817     10074   2636817
# 49  0400000US54      54     West Virginia    741544      5473    741544
# 50  0400000US55      55         Wisconsin   2288362      8293   2288362
# 51  0400000US56      56           Wyoming    223513      2812    223513
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...    HC03_VC95 HC04_VC95  \
# 47       (X)   2044422     13958      67.3    ...          0.1       0.1
# 48       (X)   1687786     13965      64.0    ...          0.1       0.1
# 49       (X)    471536      7578      63.6    ...          0.0       0.1
# 50       (X)   1461573     10805      63.9    ...          0.1       0.1
# 51       (X)    146745      3551      65.7    ...          0.1       0.1
#
#    HC01_VC96 HC02_VC96 HC03_VC96 HC04_VC96 HC01_VC98 HC02_VC98 HC03_VC98  \
# ...

# %%
ACS_11_1YR_DP02 = pd.read_csv('ACS_11_1YR_DP02_with_ann.csv')
ACS_11_1YR_DP03 = pd.read_csv('ACS_11_1YR_DP03_with_ann.csv')
ACS_11_1YR_DP04 = pd.read_csv('ACS_11_1YR_DP04_with_ann.csv')
ACS_11_1YR_DP05 = pd.read_csv('ACS_11_1YR_DP05_with_ann.csv')
frames = [ACS_11_1YR_DP02, ACS_11_1YR_DP03, ACS_11_1YR_DP04, ACS_11_1YR_DP05]
ACS_11_1YR = pd.concat(frames, axis=1)

ACS_11_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   2990650     13887   2990650
# 48  0400000US53      53        Washington   2632621      9876   2632621
# 49  0400000US54      54     West Virginia    735408      6147    735408
# 50  0400000US55      55         Wisconsin   2275352      8388   2275352
# 51  0400000US56      56           Wyoming    222539      3310    222539
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...    HC03_VC95 HC04_VC95  \
# 47       (X)   2010914     15488      67.2    ...          0.1       0.1
# 48       (X)   1699851     11753      64.6    ...          0.1       0.1
# 49       (X)    477809      7963      65.0    ...          0.0       0.1
# 50       (X)   1462927     12624      64.3    ...          0.0       0.1
# 51       (X)    142618      4167      64.1    ...          0.0       0.1
#
#    HC01_VC96 HC02_VC96 HC03_VC96 HC04_VC96 HC01_VC98 HC02_VC98 HC03_VC98  \
# ...

# %%
ACS_10_1YR_DP02 = pd.read_csv('ACS_10_1YR_DP02_with_ann.csv')
ACS_10_1YR_DP03 = pd.read_csv('ACS_10_1YR_DP03_with_ann.csv')
ACS_10_1YR_DP04 = pd.read_csv('ACS_10_1YR_DP04_with_ann.csv')
ACS_10_1YR_DP05 = pd.read_csv('ACS_10_1YR_DP05_with_ann.csv')
frames = [ACS_10_1YR_DP02, ACS_10_1YR_DP03, ACS_10_1YR_DP04, ACS_10_1YR_DP05]
ACS_10_1YR = pd.concat(frames, axis=1)

ACS_10_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   2992732     14604   2992732
# 48  0400000US53      53        Washington   2606863      9745   2606863
# 49  0400000US54      54     West Virginia    741940      5724    741940
# 50  0400000US55      55         Wisconsin   2279532      9375   2279532
# 51  0400000US56      56           Wyoming    222803      3575    222803
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...    HC03_VC95 HC04_VC95  \
# 47       (X)   2013520     16738      67.3    ...          0.1       0.1
# 48       (X)   1681386     12734      64.5    ...          0.1       0.1
# 49       (X)    485652      6805      65.5    ...          0.0       0.1
# 50       (X)   1453332     10977      63.8    ...          0.0       0.1
# 51       (X)    147394      3852      66.2    ...          0.1       0.1
#
#    HC01_VC96 HC02_VC96 HC03_VC96 HC04_VC96 HC01_VC98 HC02_VC98 HC03_VC98  \
# ...

# %%
ACS_09_1YR_DP02 = pd.read_csv('ACS_09_1YR_DP2_with_ann.csv')
ACS_09_1YR_DP03 = pd.read_csv('ACS_09_1YR_DP3_with_ann.csv')
ACS_09_1YR_DP04 = pd.read_csv('ACS_09_1YR_DP4_with_ann.csv')
ACS_09_1YR_DP05 = pd.read_csv('ACS_09_1YR_DP5_with_ann.csv')
frames = [ACS_09_1YR_DP02, ACS_09_1YR_DP03, ACS_09_1YR_DP04, ACS_09_1YR_DP05]
ACS_09_1YR = pd.concat(frames, axis=1)

ACS_09_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_EST_VC02 HC01_MOE_VC02  \
# 47  0400000US51      51          Virginia       2971489         12961
# 48  0400000US53      53        Washington       2559288          9514
# 49  0400000US54      54     West Virginia        748517          6008
# 50  0400000US55      55         Wisconsin       2272274          8949
# 51  0400000US56      56           Wyoming        213571          2941
#
#    HC02_EST_VC02 HC02_MOE_VC02 HC01_EST_VC03 HC01_MOE_VC03 HC02_EST_VC03  \
# 47       2971489           (X)       1987501         16748          66.9
# 48       2559288           (X)       1650519         12840          64.5
# 49        748517           (X)        492279          6996          65.8
# 50       2272274           (X)       1476615         10171          65.0
# 51        213571           (X)        143459          3621          67.2
#
#         ...      HC02_EST_VC83 HC02_MOE_VC83 HC01_EST_VC84 HC01_MOE_VC84  \
# ...

# %%
ACS_08_1YR_DP02 = pd.read_csv('ACS_08_1YR_DP2_with_ann.csv')
ACS_08_1YR_DP03 = pd.read_csv('ACS_08_1YR_DP3_with_ann.csv')
ACS_08_1YR_DP04 = pd.read_csv('ACS_08_1YR_DP4_with_ann.csv')
ACS_08_1YR_DP05 = pd.read_csv('ACS_08_1YR_DP5_with_ann.csv')
frames = [ACS_08_1YR_DP02, ACS_08_1YR_DP03, ACS_08_1YR_DP04, ACS_08_1YR_DP05]
ACS_08_1YR = pd.concat(frames, axis=1)

ACS_08_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_EST_VC02 HC01_MOE_VC02  \
# 47  0400000US51      51          Virginia       2961083         11010
# 48  0400000US53      53        Washington       2547663          9073
# 49  0400000US54      54     West Virginia        749586          6455
# 50  0400000US55      55         Wisconsin       2249630          8922
# 51  0400000US56      56           Wyoming        208613          3448
#
#    HC02_EST_VC02 HC02_MOE_VC02 HC01_EST_VC03 HC01_MOE_VC03 HC02_EST_VC03  \
# 47       2961083           (X)       1999409         13933          67.5
# 48       2547663           (X)       1636755         14806          64.2
# 49        749586           (X)        491152          6977          65.5
# 50       2249630           (X)       1467796         10918          65.2
# 51        208613           (X)        135678          3475          65.0
#
#         ...      HC02_EST_VC83 HC02_MOE_VC83 HC01_EST_VC84 HC01_MOE_VC84  \
# ...

# %%
ACS_07_1YR_DP02 = pd.read_csv('ACS_07_1YR_DP2_with_ann.csv')
ACS_07_1YR_DP03 = pd.read_csv('ACS_07_1YR_DP3_with_ann.csv')
ACS_07_1YR_DP04 = pd.read_csv('ACS_07_1YR_DP4_with_ann.csv')
ACS_07_1YR_DP05 = pd.read_csv('ACS_07_1YR_DP5_with_ann.csv')
frames = [ACS_07_1YR_DP02, ACS_07_1YR_DP03, ACS_07_1YR_DP04, ACS_07_1YR_DP05]
ACS_07_1YR = pd.concat(frames, axis=1)

ACS_07_1YR.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_EST_VC02 HC01_MOE_VC02  \
# 47  0400000US51      51          Virginia       2932234         11822
# 48  0400000US53      53        Washington       2501509          8669
# 49  0400000US54      54     West Virginia        733849          6909
# 50  0400000US55      55         Wisconsin       2241597          8249
# 51  0400000US56      56           Wyoming        206136          3069
#
#    HC02_EST_VC02 HC02_MOE_VC02 HC01_EST_VC03 HC01_MOE_VC03 HC02_EST_VC03  \
# 47           100           (X)       1964204         15049          67.0
# 48           100           (X)       1619537         11679          64.7
# 49           100           (X)        491383          7377          67.0
# 50           100           (X)       1461841         11443          65.2
# 51           100           (X)        135066          3714          65.5
#
#         ...      HC02_EST_VC83 HC02_MOE_VC83 HC01_EST_VC84 HC01_MOE_VC84  \
# ...

# %%
dataframes = [ACS_16_1YR, ACS_15_1YR, ACS_14_1YR, ACS_13_1YR, ACS_12_1YR, ACS_11_1YR, ACS_10_1YR, ACS_09_1YR, ACS_08_1YR, ACS_07_1YR]
ACS = pd.concat(dataframes, axis=1)
ACS.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label  \
# 0           Id     Id2         Geography
# 1  0400000US01      01           Alabama
# 2  0400000US02      02            Alaska
# 3  0400000US04      04           Arizona
# 4  0400000US05      05          Arkansas
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                          1852518
# 2                                           248468
# 3                                          2519052
# 4                                          1142718
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                              12189
# 2                                               2841
# 3                                              11479
# 4                                               7341
#
#                                         HC03_VC03  \
# ...

# %%
ACS.tail()
# Out:
#          GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 47  0400000US51      51          Virginia   3120692     13161   3120692
# 48  0400000US53      53        Washington   2768076      8506   2768076
# 49  0400000US54      54     West Virginia    722125      5656    722125
# 50  0400000US55      55         Wisconsin   2326998      7745   2326998
# 51  0400000US56      56           Wyoming    223619      4088    223619
#
#    HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04      ...      HC02_EST_VC83  \
# 47       (X)   2063049     16402      66.1      ...                0.1
# 48       (X)   1784043     12484      64.5      ...                0.1
# 49       (X)    467396      6711      64.7      ...                0.0
# 50       (X)   1460922      9966      62.8      ...                0.0
# 51       (X)    145524      4006      65.1      ...                0.0
#
#    HC02_MOE_VC83 HC01_EST_VC84 HC01_MOE_VC84 HC02_EST_VC84 HC02_MOE_VC84  \
# ...

# %%
ACS.rename(columns={'Geography': 'State', 'Id2': 'ID'}, inplace=True)

# %%
ACS = ACS.reindex(ACS.index.drop(0)).drop('Id', axis=1)
ACS
# Out:
#          GEO.id GEO.id2     GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 1   0400000US01      01               Alabama   1852518     12189   1852518
# 2   0400000US02      02                Alaska    248468      2841    248468
# 3   0400000US04      04               Arizona   2519052     11479   2519052
# 4   0400000US05      05              Arkansas   1142718      7341   1142718
# 5   0400000US06      06            California  12944178     15703  12944178
# 6   0400000US08      08              Colorado   2108992      7767   2108992
# 7   0400000US09      09           Connecticut   1357269      7141   1357269
# 8   0400000US10      10              Delaware    351085      3936    351085
# 9   0400000US11      11  District of Columbia    281241      3152    281241
# 10  0400000US12      12               Florida   7573456     23478   7573456
# 11  0400000US13      13               Georgia   3686135     15528   3686135
# ...

# %%
ACS.dtypes.value_counts()
# Out:
# object    20272
# dtype: int64

# %%
pd.to_numeric(ACS[(:, 3:)], errors='coerce')
# Out:
#   File "<ipython-input-39-f43f5a0c10c9>", line 1
#     pd.to_numeric(ACS[(:, 3:)], errors='coerce')
#                        ^
# SyntaxError: invalid syntax

# %%
ACS[['HC01_VC03', 'HC02_VC03']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "*****"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-4d4c0648d654> in <module>()
# ----> 1 ACS[['HC01_VC03', 'HC02_VC03']].apply(pd.to_numeric)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ...

# %%
ACS[['HC01_VC03', 'HC02_VC03']]
# Out:
#    HC01_VC03 HC01_VC03 HC01_VC03 HC01_VC03 HC01_VC03 HC01_VC03 HC01_VC03  \
# 1    1852518   3897741   2230180   4863300   1846390   3878471   2218391
# 2     248468    575088    310672    741894    250185    571393    309453
# 3    2519052   5483490   2961136   6931071   2463008   5393214   2929173
# 4    1142718   2358465   1354801   2988248   1144663   2352507   1347598
# 5   12944178  31191530  14061375  39250017  12896357  31068647  13988399
# 6    2108992   4417829   2339140   5540545   2074735   4333738   2309122
# 7    1357269   2919678   1499145   3576452   1343703   2922877   1496056
# 8     351085    771059    426154    952065    352595    765250    421734
# 9     281241    569932    313703    681170    281787    564206    309596
# 10   7573456  16950176   9302140  20612439   7463184  16640196   9210287
# 11   3686135   8085411   4219103  10310371   3656407   7998548   4182228
# 12    455868   1152321    537170   1428557    445936   1152884    532413
# ...

# %%
ACS[[:,(3:5)]].apply(pd.to_numeric)
# Out:
#   File "<ipython-input-43-0fc136405910>", line 1
#     ACS[[:,(3:5)]].apply(pd.to_numeric)
#          ^
# SyntaxError: invalid syntax

# %%
TAPP_2016 = pd.read_csv('TAPP 2016 Presidential Election Results.csv')
TAPP_2016.head()
# Out:
#         STATE TOTAL VOTES Democratic Votes Democratic Vote % Republican Votes  \
# 0     Alabama   2,123,372          729,547            34.40%        1,318,255
# 1      Alaska     318,608          116,454            36.60%          163,387
# 2     Arizona   2,573,165        1,161,167            45.10%        1,252,401
# 3    Arkansas   1,130,635          380,494            33.70%          684,872
# 4  California  14,181,595        8,753,788            61.70%        4,483,810
#
#   Republican Vote % Libertarian Votes Libertarian Vote %
# 0            62.10%            44,467              2.10%
# 1            51.30%            18,725              5.90%
# 2            48.70%           106,327              4.10%
# 3            60.60%            29,829              2.60%
# 4            31.60%           478,500              3.40%

# %%
TAPP_2016.tail()
# Out:
#             STATE  TOTAL VOTES Democratic Votes Democratic Vote %  \
# 47     Washington    3,209,214        1,742,718            54.30%
# 48  West Virginia      713,051          188,794            26.50%
# 49      Wisconsin    2,976,150        1,382,536            46.50%
# 50        Wyoming      255,849           55,973            21.90%
# 51         Totals  136,559,088       65,853,516            48.20%
#
#    Republican Votes Republican Vote % Libertarian Votes Libertarian Vote %
# 47        1,221,747            38.10%           160,879              5.00%
# 48          489,371            68.60%            23,004              3.20%
# 49        1,405,284            47.20%           106,674              3.60%
# 50          174,419            68.20%            13,287              5.20%
# 51       62,984,824            46.10%         4,489,221              3.30%

# %%
TAPP_2016.dtypes
# Out:
# STATE                 object
# TOTAL VOTES           object
# Democratic Votes      object
# Democratic Vote %     object
# Republican Votes      object
# Republican Vote %     object
# Libertarian Votes     object
# Libertarian Vote %    object
# dtype: object

# %%
TAPP_2016 = TAPP_2016[TAPP_2016.STATE != 'Totals']
TAPP_2016
# Out:
#              STATE TOTAL VOTES Democratic Votes Democratic Vote %  \
# 0          Alabama   2,123,372          729,547            34.40%
# 1           Alaska     318,608          116,454            36.60%
# 2          Arizona   2,573,165        1,161,167            45.10%
# 3         Arkansas   1,130,635          380,494            33.70%
# 4       California  14,181,595        8,753,788            61.70%
# 5         Colorado   2,780,220        1,338,870            48.20%
# 6      Connecticut   1,644,920          897,572            54.60%
# 7         Delaware     441,590          235,603            53.40%
# 8    Dist. of Col.     311,268          282,830            90.90%
# 9          Florida   9,420,039        4,504,975            47.80%
# 10         Georgia   4,092,373        1,877,963            45.90%
# 11          Hawaii     428,937          266,891            62.20%
# 12           Idaho     690,255          189,765            27.50%
# ...

# %%
TAPP_2016.rename({'Dist. of Col.':'District of Columbia'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-31a86cab5bd9> in <module>()
# ----> 1 TAPP_2016['STATE'].rename(columns={'Dist. of Col.':'District of Columbia'}, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ...
